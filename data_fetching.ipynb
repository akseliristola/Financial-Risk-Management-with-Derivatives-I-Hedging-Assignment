# %%
import numpy as np
import pandas as pd
from datetime import datetime, timedelta

import refinitiv.dataplatform.eikon as ek
import option_ric_tools as ort

ek.set_app_key('DEFAULT_CODE_BOOK_APP_KEY')
# Out:
# ERROR!!! An error occurred while requesting URL('http://localhost:9000/api/status').
#      ConnectError('All connection attempts failed')
# ERROR!!! An error occurred while requesting URL('http://localhost:9060/api/status').
#      ConnectError('All connection attempts failed')
# Error: no proxy address identified.
# Check if Desktop is running.
# ERROR!!! An error occurred while requesting URL('http://localhost:9000/api/handshake').
#      ConnectError('All connection attempts failed')
# ERROR!!! An error occurred while requesting URL('http://localhost:9000/api/status').
#      ConnectError('All connection attempts failed')
# ERROR!!! An error occurred while requesting URL('http://localhost:9060/api/status').
#      ConnectError('All connection attempts failed')
# Error: no proxy address identified.
# Check if Desktop is running.
# ERROR!!! An error occurred while requesting URL('http://localhost:9000/api/handshake').
#      ConnectError('All connection attempts failed')

# %% [markdown]
# Let's start by defining what data we will be fetching. We will need to define the following:
# * The ISIN for the underlying security as a string
# * The maturity date for any options as a string
# * The strike prices for which to fetch options prices as a list of integers
# * The kinds of options (call/put) to fetch prices for as a list of strings (allowed values are 'C' and 'P')
#
# An example for IBM is provided below. If you are unsure what strikes to fetch you might want to check the price of the underlying 90 days prior to your chosen maturity. Any configurations for which no prices are available will be skipped.

# %%
isin = 'US4592001014'
maturities = ['2025-9-12','2025-9-19','2025-9-26','2025-11-28','2025-11-21','2025-10-31','2025-10-24', '2025-11-14', '2025-10-10','2025-10-17']
strikes = [115, 120, 125, 130, 135]
kinds = ['C', 'P']

# %% [markdown]
# The code below will then try to fetch pricing for what we defined. Using the Eikon API requires quite a lot of preprocessing, which is taken care of in the file 'option_ric_tools.py' The price series for each option will be added as a column.

# %%
# Get RIC for the underlying (same for all maturities)
ric = ek.get_symbology(symbol=isin, from_symbol_type='ISIN', to_symbol_type='RIC').iloc[0,0]

# Number of days of data to include (approximately 45 days)
target_days = 45

# Loop through each maturity
for maturity in maturities:
    print(f'\n{"="*60}')
    print(f'Processing maturity: {maturity}')
    print(f'{"="*60}')
    
    # Calculate the date range for approximately 45 days before maturity
    maturity_date = pd.Timestamp(maturity)
    today = pd.Timestamp(datetime.now().date())
    
    # End date is the earlier of maturity date or today
    end_date = min(maturity_date, today)
    # Start date is 45 days before end date
    start_date = end_date - timedelta(days=target_days)
    
    sdate = start_date.strftime('%Y-%m-%d')
    edate = end_date.strftime('%Y-%m-%d')
    
    print(f'Target date range: {sdate} to {edate} (approximately {target_days} days)')
    
    price_dfs = []
    for kind in kinds:
        assert kind in ['C', 'P']
        for strike in strikes:
            kind_str = 'call' if kind == 'C' else 'put'
            print(f'\nFetching prices for {kind_str} option with strike price {strike}')
            rics, prices_list = ort.get_optionRic(isin, maturity, strike, kind)
            try:
                price_df = prices_list[0]
                price_df = price_df.drop(['BID', 'ASK'], axis=1)
                price_df.columns = [f'{kind}{strike}']
                price_dfs.append(price_df)
            except IndexError:
                print('Skipping empty combination')
    
    if not price_dfs:
        print(f'No data found for maturity {maturity}, skipping...')
        continue
    
    price_df = pd.concat(price_dfs, axis=1)
    
    # Filter data to the target date range (approximately 45 days)
    price_df = price_df[(price_df.index >= start_date) & (price_df.index <= end_date)]
    
    if price_df.empty:
        print(f'No data available in the target date range for maturity {maturity}, skipping...')
        continue
    
    # Fetch underlying stock prices for the same date range
    stock = ek.get_timeseries(
        rics=[ric],
        fields=['CLOSE'],
        start_date=sdate,
        end_date=edate,
        interval='daily'
    )
    
    stock = stock.reset_index()
    stock.columns.name = None
    stock.index = stock['Date']
    stock.index.name = None
    stock = stock.drop('Date', axis=1)
    stock.columns = ['Underlying']
    
    # Filter stock data to match the same date range
    stock = stock[(stock.index >= start_date) & (stock.index <= end_date)]
    
    # Join underlying with options data
    price_df = stock.join(price_df)
    
    # Remove any rows with all NaN values (in case of date mismatches)
    price_df = price_df.dropna(how='all')
    
    # Check actual number of days in the dataset
    actual_days = len(price_df)
    print(f'\nActual number of trading days in dataset: {actual_days}')
    
    # Save to CSV with date in filename
    price_df.index.name = 'Date'
    price_df = price_df.reset_index()
    
    # Format date for filename (replace dashes with underscores)
    date_str = maturity.replace('-', '_')
    filename = f'data/options_data_{date_str}.csv'
    price_df.to_csv(filename, index=False)
    print(f'Saved data to {filename}')
# Out:
# Fetching prices for call option with strike price 115
# ---------------------------------------------------------------------------
# EndpointError                             Traceback (most recent call last)
# Cell In[9], line 7
#       5 kind_str = 'call' if kind == 'C' else 'P'
#       6 print(f'\nFetching prices for {kind_str} option with strike price {strike}')
# ----> 7 rics, prices_list = ort.get_optionRic(isin, maturity, strike, kind)
#       8 try:
#       9     price_df = prices_list[0]
#
# File ~/projektit/fina/option_ric_tools.py:325, in get_optionRic(isin, maturity, strike, opt_type)
#     317 exchanges = {'OPQ': get_ric_opra,
#     318        'IEU': get_ric_ieu,
#     319        'EUX': get_ric_eurex,
#     320        'HKG': get_ric_hk,
#     321        'HFE': get_ric_hk,
#     322        'OSA': get_ric_ose}
#     324 # convert ISIN to RIC
# --> 325 df = rdp.convert_symbols( isin, from_symbol_type = "ISIN" , to_symbol_types = "RIC")
#     326 ricUnderlying = df['RIC'][0]
#     328 # get exchanges codes where the option on the given asset is traded
#
# File ~/projektit/fina/.venv/lib/python3.9/site-packages/refinitiv/dataplatform/factory/content_factory.py:826, in convert_symbols(symbols, from_symbol_type, to_symbol_types)
#     825 def convert_symbols(symbols, from_symbol_type=SymbolTypes.RIC, to_symbol_types=None):
# --> 826     return ContentFactory._convert_symbols(
#     827         symbols=symbols,
#     828         from_symbol_type=from_symbol_type,
#     829         to_symbol_types=to_symbol_types,
#     830     )
#
# File ~/projektit/fina/.venv/lib/python3.9/site-packages/refinitiv/dataplatform/factory/content_factory.py:558, in ContentFactory._convert_symbols(cls, symbols, from_symbol_type, to_symbol_types, on_response, closure)
#     556 session = ContentFactory.get_default_session()
#     557 symbology = Symbology(session=session, on_response=on_response)
# --> 558 symbology_response = symbology._convert(
#     559     symbols=symbols,
#     560     from_symbol_type=from_symbol_type,
#     561     to_symbol_types=to_symbol_types,
#     562     closure=closure,
#     563 )
#     564 cls._last_result = symbology_response
#     565 if (
#     566     symbology_response.is_success
#     567     and symbology_response.data
#     568     and symbology_response.data.df is not None
#     569 ):
#
# File ~/projektit/fina/.venv/lib/python3.9/site-packages/refinitiv/dataplatform/content/symbology/symbology.py:81, in Symbology._convert(self, symbols, from_symbol_type, to_symbol_types, closure)
#      74 def _convert(
#      75     self,
#      76     symbols,
#    (...)
#      79     closure=None,
#      80 ):
# ---> 81     return self._lookup._endpoint.session._loop.run_until_complete(
#      82         self._convert_async(
#      83             symbols=symbols,
#      84             from_symbol_type=from_symbol_type,
#      85             to_symbol_types=to_symbol_types,
#      86             closure=closure,
#      87         )
#      88     )
#
# File ~/projektit/fina/.venv/lib/python3.9/site-packages/nest_asyncio.py:98, in _patch_loop.<locals>.run_until_complete(self, future)
#      95 if not f.done():
#      96     raise RuntimeError(
#      97         'Event loop stopped before Future completed.')
# ---> 98 return f.result()
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/asyncio/futures.py:201, in Future.result(self)
#     199 self.__log_traceback = False
#     200 if self._exception is not None:
# --> 201     raise self._exception
#     202 return self._result
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/asyncio/tasks.py:256, in Task.__step(***failed resolving arguments***)
#     252 try:
#     253     if exc is None:
#     254         # We use the `send` method directly, because coroutines
#     255         # don't have `__iter__` and `__next__` methods.
# --> 256         result = coro.send(None)
#     257     else:
#     258         result = coro.throw(exc)
#
# File ~/projektit/fina/.venv/lib/python3.9/site-packages/refinitiv/dataplatform/content/symbology/symbology.py:97, in Symbology._convert_async(self, symbols, from_symbol_type, to_symbol_types, closure)
#      90 async def _convert_async(
#      91     self,
#      92     symbols,
#    (...)
#      95     closure=None,
#      96 ):
# ---> 97     return await self.__convert(
#      98         symbols=symbols,
#      99         from_symbol_type=from_symbol_type,
#     100         to_symbol_types=to_symbol_types,
#     101         closure=closure,
#     102     )
#
# File ~/projektit/fina/.venv/lib/python3.9/site-packages/refinitiv/dataplatform/content/symbology/symbology.py:128, in Symbology.__convert(self, symbols, from_symbol_type, to_symbol_types, closure)
#     125 if isinstance(symbols, list):
#     126     symbols = ",".join(symbols)
# --> 128 response = await self._lookup._lookup_async(
#     129     view=SearchViews.SearchAll,
#     130     terms=symbols,
#     131     scope=from_symbol_type,
#     132     select=select,
#     133     closure=closure,
#     134 )
#     136 return response
#
# File ~/projektit/fina/.venv/lib/python3.9/site-packages/refinitiv/dataplatform/content/search/Lookup.py:240, in Lookup._lookup_async(self, view, terms, scope, select, filter, boost, closure)
#     235 bodyParameters = self._constuctBodyParameters(
#     236     view, terms, scope, select, filter, boost
#     237 )
#     239 #   send the request asynchronously
# --> 240 response = await self._endpoint.send_request_async(
#     241     method=Endpoint.RequestMethod.POST,
#     242     header_parameters={"Content-Type": "application/json"},
#     243     body_parameters=bodyParameters,
#     244     closure=closure,
#     245 )
#     247 #   store the response
#     248 # warning IMRPOVE_ME :: THIS IS A WORKAROUND FOR CONVERT GENERAL ENDPOINT RESPONSE TO THIS SPECIFIC LOOKUP RESPONSE
#     249 self._response = response
#
# File ~/projektit/fina/.venv/lib/python3.9/site-packages/refinitiv/dataplatform/delivery/data/endpoint.py:551, in Endpoint.send_request_async(self, method, header_parameters, path_parameters, query_parameters, body_parameters, closure)
#     548     self.on_response(_result)
#     549     return _result
# --> 551 raise EndpointError(-1, "Session is not opened. Can't send any request")
#
# EndpointError: Error code -1 | Session is not opened. Can't send any request

# %%
# All data has been saved to CSV files in the data folder
# Each file is named: options_data_YYYY_MM_DD.csv
print("Processing complete! Check the data folder for CSV files.")
# Out:
#             C115   C120  C125  C130  C135  P115  P120  P125  P130  P135
# 2021-12-20  <NA>   9.81   6.9  4.44  2.81  2.84  3.95   6.6  9.45  <NA>
# 2021-12-21  <NA>   11.6  7.91     5  3.15  2.05   3.1   4.9  7.45  <NA>
# 2021-12-22  <NA>   11.6  8.06   5.2  3.15  1.77  2.85  4.36   6.9  <NA>
# 2021-12-23  <NA>   12.7   8.4   5.7  3.45  1.52  2.44  3.75  5.95  8.87
# 2021-12-27  <NA>  13.05   9.1  5.75   3.5  1.36  2.12  3.45   5.4   8.5

# %% [markdown]
# The code above now processes all maturities in the list. For each maturity:
# * Fetches option prices for all strike prices and option types
# * Fetches the underlying stock prices for the same time period
# * Saves the combined data to a CSV file in the data folder with the format: `options_data_YYYY_MM_DD.csv`

# %%
# RIC is now fetched once at the beginning of the loop (in cell 4)
# This cell is no longer needed
# Out:
# ERROR!!! An error occurred while requesting URL('http://localhost:9000/api/udf').
#      ConnectError('All connection attempts failed')
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File ~/projektit/fina/.venv/lib/python3.9/site-packages/httpx/_transports/default.py:67, in map_httpcore_exceptions()
#      66 try:
# ---> 67     yield
#      68 except Exception as exc:
#
# File ~/projektit/fina/.venv/lib/python3.9/site-packages/httpx/_transports/default.py:371, in AsyncHTTPTransport.handle_async_request(self, request)
#     370 with map_httpcore_exceptions():
# --> 371     resp = await self._pool.handle_async_request(req)
#     373 assert isinstance(resp.stream, typing.AsyncIterable)
#
# File ~/projektit/fina/.venv/lib/python3.9/site-packages/httpcore/_async/connection_pool.py:256, in AsyncConnectionPool.handle_async_request(self, request)
#     255     await self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#
# File ~/projektit/fina/.venv/lib/python3.9/site-packages/httpcore/_async/connection_pool.py:236, in AsyncConnectionPool.handle_async_request(self, request)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = await connection.handle_async_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#
# File ~/projektit/fina/.venv/lib/python3.9/site-packages/httpcore/_async/connection.py:101, in AsyncHTTPConnection.handle_async_request(self, request)
#     100     self._connect_failed = True
# --> 101     raise exc
#     103 return await self._connection.handle_async_request(request)
#
# File ~/projektit/fina/.venv/lib/python3.9/site-packages/httpcore/_async/connection.py:78, in AsyncHTTPConnection.handle_async_request(self, request)
#      77 if self._connection is None:
# ---> 78     stream = await self._connect(request)
#      80     ssl_object = stream.get_extra_info("ssl_object")
#
# File ~/projektit/fina/.venv/lib/python3.9/site-packages/httpcore/_async/connection.py:124, in AsyncHTTPConnection._connect(self, request)
#     123 async with Trace("connect_tcp", logger, request, kwargs) as trace:
# --> 124     stream = await self._network_backend.connect_tcp(**kwargs)
#     125     trace.return_value = stream
#
# File ~/projektit/fina/.venv/lib/python3.9/site-packages/httpcore/_backends/auto.py:31, in AutoBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#      30 await self._init_backend()
# ---> 31 return await self._backend.connect_tcp(
#      32     host,
#      33     port,
#      34     timeout=timeout,
#      35     local_address=local_address,
#      36     socket_options=socket_options,
#      37 )
#
# File ~/projektit/fina/.venv/lib/python3.9/site-packages/httpcore/_backends/anyio.py:122, in AnyIOBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#     121         for option in socket_options:
# --> 122             stream._raw_socket.setsockopt(*option)  # type: ignore[attr-defined] # pragma: no cover
#     123 return AnyIOStream(stream)
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/contextlib.py:135, in _GeneratorContextManager.__exit__(self, type, value, traceback)
#     134 try:
# --> 135     self.gen.throw(type, value, traceback)
#     136 except StopIteration as exc:
#     137     # Suppress StopIteration *unless* it's the same exception that
#     138     # was passed to throw().  This prevents a StopIteration
#     139     # raised inside the "with" statement from being suppressed.
#
# File ~/projektit/fina/.venv/lib/python3.9/site-packages/httpcore/_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# ConnectError: All connection attempts failed
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 ric = ek.get_symbology(symbol=isin, from_symbol_type='ISIN', to_symbol_type='RIC').iloc[0,0]
#       2 sdate = str(price_df.index.min().date())
#       3 edate = str(price_df.index.max().date())
#
# File ~/projektit/fina/.venv/lib/python3.9/site-packages/refinitiv/dataplatform/legacy/symbology.py:146, in get_symbology(symbol, from_symbol_type, to_symbol_type, raw_output, debug, best_match)
#     138         raise ValueError(error_msg)
#     140 payload = {
#     141     "symbols": symbol,
#     142     "from": from_symbol_type,
#     143     "to": to_symbol_type,
#     144     "bestMatchOnly": best_match,
#     145 }
# --> 146 response = refinitiv.dataplatform.legacy.json_requests.send_json_request(
#     147     Symbology_UDF_endpoint, payload, debug=debug
#     148 )
#     149 result = response.json()
#     150 if raw_output:
#
# File ~/projektit/fina/.venv/lib/python3.9/site-packages/refinitiv/dataplatform/legacy/json_requests.py:90, in send_json_request(entity, payload, ID, debug, raw_response)
#      86 udf_request = {"Entity": {"E": entity, "W": data}, "ID": ID}
#      87 logger.debug(
#      88     "Request to {} :{}".format(_session._get_udf_url(), udf_request)
#      89 )
# ---> 90 response = _session.http_request(
#      91     method="POST",
#      92     url=_session._get_udf_url(),
#      93     headers={"Content-Type": "application/json"},
#      94     # "x-tr-applicationid": _session.app_key},
#      95     json=udf_request,
#      96 )
#      98 try:
#      99     logger.debug("HTTP Response code: {}".format(response.status_code))
#
# File ~/projektit/fina/.venv/lib/python3.9/site-packages/refinitiv/dataplatform/core/session/session.py:1523, in Session.http_request(self, url, method, headers, data, params, json, auth, loop, **kwargs)
#    1520 if loop is None:
#    1521     loop = self._loop
# -> 1523 response = loop.run_until_complete(
#    1524     self.http_request_async(
#    1525         url, method, headers, data, params, json, auth, **kwargs
#    1526     )
#    1527 )
#    1528 return response
#
# File ~/projektit/fina/.venv/lib/python3.9/site-packages/nest_asyncio.py:98, in _patch_loop.<locals>.run_until_complete(self, future)
#      95 if not f.done():
#      96     raise RuntimeError(
#      97         'Event loop stopped before Future completed.')
# ---> 98 return f.result()
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/asyncio/futures.py:201, in Future.result(self)
#     199 self.__log_traceback = False
#     200 if self._exception is not None:
# --> 201     raise self._exception
#     202 return self._result
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/asyncio/tasks.py:256, in Task.__step(***failed resolving arguments***)
#     252 try:
#     253     if exc is None:
#     254         # We use the `send` method directly, because coroutines
#     255         # don't have `__iter__` and `__next__` methods.
# --> 256         result = coro.send(None)
#     257     else:
#     258         result = coro.throw(exc)
#
# File ~/projektit/fina/.venv/lib/python3.9/site-packages/refinitiv/dataplatform/core/session/desktop_session.py:516, in DesktopSession.http_request_async(self, url, method, headers, data, params, json, closure, auth, loop, **kwargs)
#     503 async def http_request_async(
#     504     self,
#     505     url: str,
#    (...)
#     514     **kwargs,
#     515 ):
# --> 516     return await self._http_request_async(
#     517         url,
#     518         method=method,
#     519         headers=headers,
#     520         data=data,
#     521         params=params,
#     522         json=json,
#     523         closure=closure,
#     524         auth=auth,
#     525         loop=loop,
#     526         **kwargs,
#     527     )
#
# File ~/projektit/fina/.venv/lib/python3.9/site-packages/refinitiv/dataplatform/core/session/session.py:1495, in Session._http_request_async(self, url, method, headers, data, params, json, closure, auth, loop, **kwargs)
#    1491 except httpx.RequestError as error:
#    1492     self.error(
#    1493         f"ERROR!!! An error occurred while requesting {error.request.url!r}.\n     {error!r}"
#    1494     )
# -> 1495     raise error
#    1497 assert request_response is not None
#    1498 self.debug(
#    1499     f"HTTP request response {request_response.status_code}: {request_response.text}"
#    1500 )
#
# File ~/projektit/fina/.venv/lib/python3.9/site-packages/refinitiv/dataplatform/core/session/session.py:1481, in Session._http_request_async(self, url, method, headers, data, params, json, closure, auth, loop, **kwargs)
#    1476 assert isinstance(kwargs["timeout"], int) or isinstance(
#    1477     kwargs["timeout"], float
#    1478 ), "ERROR!!! HTTP request timeout must be int or float"
#    1480 try:
# -> 1481     request_response = await self._http_session.request(
#    1482         method,
#    1483         url,
#    1484         headers=headers,
#    1485         data=data,
#    1486         params=params,
#    1487         json=json,
#    1488         cookies=cookies,
#    1489         **kwargs,
#    1490     )
#    1491 except httpx.RequestError as error:
#    1492     self.error(
#    1493         f"ERROR!!! An error occurred while requesting {error.request.url!r}.\n     {error!r}"
#    1494     )
#
# File ~/projektit/fina/.venv/lib/python3.9/site-packages/httpx/_client.py:1559, in AsyncClient.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#    1530 """
#    1531 Build and send a request.
#    1532
#    (...)
#    1544 [0]: /advanced/#merging-of-configuration
#    1545 """
#    1546 request = self.build_request(
#    1547     method=method,
#    1548     url=url,
#    (...)
#    1557     extensions=extensions,
#    1558 )
# -> 1559 return await self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File ~/projektit/fina/.venv/lib/python3.9/site-packages/httpx/_client.py:1646, in AsyncClient.send(self, request, stream, auth, follow_redirects)
#    1638 follow_redirects = (
#    1639     self.follow_redirects
#    1640     if isinstance(follow_redirects, UseClientDefault)
#    1641     else follow_redirects
#    1642 )
#    1644 auth = self._build_request_auth(request, auth)
# -> 1646 response = await self._send_handling_auth(
#    1647     request,
#    1648     auth=auth,
#    1649     follow_redirects=follow_redirects,
#    1650     history=[],
#    1651 )
#    1652 try:
#    1653     if not stream:
#
# File ~/projektit/fina/.venv/lib/python3.9/site-packages/httpx/_client.py:1674, in AsyncClient._send_handling_auth(self, request, auth, follow_redirects, history)
#    1671 request = await auth_flow.__anext__()
#    1673 while True:
# -> 1674     response = await self._send_handling_redirects(
#    1675         request,
#    1676         follow_redirects=follow_redirects,
#    1677         history=history,
#    1678     )
#    1679     try:
#    1680         try:
#
# File ~/projektit/fina/.venv/lib/python3.9/site-packages/httpx/_client.py:1711, in AsyncClient._send_handling_redirects(self, request, follow_redirects, history)
#    1708 for hook in self._event_hooks["request"]:
#    1709     await hook(request)
# -> 1711 response = await self._send_single_request(request)
#    1712 try:
#    1713     for hook in self._event_hooks["response"]:
#
# File ~/projektit/fina/.venv/lib/python3.9/site-packages/httpx/_client.py:1748, in AsyncClient._send_single_request(self, request)
#    1743     raise RuntimeError(
#    1744         "Attempted to send an sync request with an AsyncClient instance."
#    1745     )
#    1747 with request_context(request=request):
# -> 1748     response = await transport.handle_async_request(request)
#    1750 assert isinstance(response.stream, AsyncByteStream)
#    1751 response.request = request
#
# File ~/projektit/fina/.venv/lib/python3.9/site-packages/httpx/_transports/default.py:371, in AsyncHTTPTransport.handle_async_request(self, request)
#     358 req = httpcore.Request(
#     359     method=request.method,
#     360     url=httpcore.URL(
#    (...)
#     368     extensions=request.extensions,
#     369 )
#     370 with map_httpcore_exceptions():
# --> 371     resp = await self._pool.handle_async_request(req)
#     373 assert isinstance(resp.stream, typing.AsyncIterable)
#     375 return Response(
#     376     status_code=resp.status,
#     377     headers=resp.headers,
#     378     stream=AsyncResponseStream(resp.stream),
#     379     extensions=resp.extensions,
#     380 )
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/contextlib.py:135, in _GeneratorContextManager.__exit__(self, type, value, traceback)
#     133     value = type()
#     134 try:
# --> 135     self.gen.throw(type, value, traceback)
#     136 except StopIteration as exc:
#     137     # Suppress StopIteration *unless* it's the same exception that
#     138     # was passed to throw().  This prevents a StopIteration
#     139     # raised inside the "with" statement from being suppressed.
#     140     return exc is not value
#
# File ~/projektit/fina/.venv/lib/python3.9/site-packages/httpx/_transports/default.py:84, in map_httpcore_exceptions()
#      81     raise
#      83 message = str(exc)
# ---> 84 raise mapped_exc(message) from exc
#
# ConnectError: All connection attempts failed

# %% [markdown]
# The underlying stock prices are now fetched within the loop for each maturity.

# %%
# Stock data fetching is now done within the loop (in cell 4)
# This cell is no longer needed

# %%
# Data preview is no longer needed here since each maturity is saved separately
# You can load any CSV file to preview the data
# Out:
#             Underlying  C115   C120  C125  C130  C135  P115  P120  P125  P130  \
# 2021-12-20      127.06  <NA>   9.81   6.9  4.44  2.81  2.84  3.95   6.6  9.45
# 2021-12-21      128.97  <NA>   11.6  7.91     5  3.15  2.05   3.1   4.9  7.45
# 2021-12-22      129.75  <NA>   11.6  8.06   5.2  3.15  1.77  2.85  4.36   6.9
# 2021-12-23      130.63  <NA>   12.7   8.4   5.7  3.45  1.52  2.44  3.75  5.95
# 2021-12-27      131.62  <NA>  13.05   9.1  5.75   3.5  1.36  2.12  3.45   5.4
#
#             P135
# 2021-12-20  <NA>
# 2021-12-21  <NA>
# 2021-12-22  <NA>
# 2021-12-23  8.87
# 2021-12-27   8.5

# %% [markdown]
# Each maturity's data is automatically saved to a CSV file in the data folder. The files are named with the format: `options_data_YYYY_MM_DD.csv`

# %%
# CSV saving is now done within the loop (in cell 4)
# This cell is no longer needed
